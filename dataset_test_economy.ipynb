# %%
import pandas as pd

# %%
df_country_serie = pd.read_csv('WDICountry-Series.csv')
df_country = pd.read_csv('WDICountry.csv')
df_data = pd.read_csv('WDIData.csv')
df_time_serie = pd.read_csv('WDISeries-Time.csv')
df_time = pd.read_csv('WDISeries.csv')

# %%
df_country_serie.head(3)
# Out:
#   CountryCode      SeriesCode  \
# 0         ABW  ST.INT.TVLX.CD
# 1         ABW  ST.INT.TRNX.CD
# 2         ABW  ST.INT.TVLR.CD
#
#                                          DESCRIPTION  Unnamed: 3
# 0  Compiled from data reported in the Internation...         NaN
# 1  Compiled from data reported in the Internation...         NaN
# 2  Compiled from data reported in the Internation...         NaN

# %%
df_country.head(3)
# Out:
#   Country Code                   Short Name                   Table Name  \
# 0          ABW                        Aruba                        Aruba
# 1          AFE  Africa Eastern and Southern  Africa Eastern and Southern
# 2          AFG                  Afghanistan                  Afghanistan
#
#                       Long Name 2-alpha code   Currency Unit  \
# 0                         Aruba           AW   Aruban florin
# 1   Africa Eastern and Southern           ZH             NaN
# 2  Islamic State of Afghanistan           AF  Afghan afghani
#
#                                        Special Notes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  Fiscal year end: March 20; reporting period fo...
#
#                       Region Income Group WB-2 code  ...  \
# 0  Latin America & Caribbean  High income        AW  ...
# 1                        NaN          NaN        ZH  ...
# ...

# %%
df_country['Region'].unique()
# Out:
# array(['Latin America & Caribbean', nan, 'South Asia',
#        'Sub-Saharan Africa', 'Europe & Central Asia',
#        'Middle East & North Africa', 'East Asia & Pacific',
#        'North America'], dtype=object)

# %%
df_data.head(3)
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2012       2013       2014  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  16.320475  16.643243  16.994695
# 1   NaN   NaN   NaN   NaN   NaN  ...  32.224027  32.046478  31.323579
# 2   NaN   NaN   NaN   NaN   NaN  ...  20.525353  19.461383  17.790698
#
#         2015       2016       2017       2018       2019  2020  Unnamed: 65
# 0  17.313168  17.604950        NaN        NaN        NaN   NaN          NaN
# ...

# %%
df_time_serie.head(3)
# Out:
#        SeriesCode    Year                                        DESCRIPTION  \
# 0  SP.DYN.AMRT.FE  YR1960  Interpolated using data for 1957 and 1962, if ...
# 1  SP.DYN.AMRT.MA  YR1960  Interpolated using data for 1957 and 1962, if ...
# 2     SP.ADO.TFRT  YR1960         Interpolated using data for 1957 and 1962.
#
#    Unnamed: 3
# 0         NaN
# 1         NaN
# 2         NaN

# %%
df_time.head(3)
# Out:
#          Series Code                                 Topic  \
# 0     AG.AGR.TRAC.NO  Environment: Agricultural production
# 1  AG.CON.FERT.PT.ZS  Environment: Agricultural production
# 2     AG.CON.FERT.ZS  Environment: Agricultural production
#
#                                       Indicator Name Short definition  \
# 0                   Agricultural machinery, tractors              NaN
# 1  Fertilizer consumption (% of fertilizer produc...              NaN
# 2  Fertilizer consumption (kilograms per hectare ...              NaN
#
#                                      Long definition Unit of measure  \
# 0  Agricultural machinery refers to the number of...             NaN
# 1  Fertilizer consumption measures the quantity o...             NaN
# 2  Fertilizer consumption measures the quantity o...             NaN
#
#   Periodicity Base Period Other notes Aggregation method  ...  \
# 0      Annual         NaN         NaN                Sum  ...
# ...

# %%
df.fillna(0)
# Out:
#       iso3 iso2  imfn      country              region      income  year  \
# 0      AFG   AF   512  Afghanistan          South Asia  Low income  1960
# 1      AFG   AF   512  Afghanistan          South Asia  Low income  1961
# 2      AFG   AF   512  Afghanistan          South Asia  Low income  1962
# 3      AFG   AF   512  Afghanistan          South Asia  Low income  1963
# 4      AFG   AF   512  Afghanistan          South Asia  Low income  1964
# ...    ...  ...   ...          ...                 ...         ...   ...
# 12407  ZWE   ZW   698     Zimbabwe  Sub-Saharan Africa  Low income  2013
# 12408  ZWE   ZW   698     Zimbabwe  Sub-Saharan Africa  Low income  2014
# 12409  ZWE   ZW   698     Zimbabwe  Sub-Saharan Africa  Low income  2015
# 12410  ZWE   ZW   698     Zimbabwe  Sub-Saharan Africa  Low income  2016
# 12411  ZWE   ZW   698     Zimbabwe  Sub-Saharan Africa  Low income  2017
#
#        gfddai01  gfddai02  gfddai03  ...  gfddoi18  gfddoi19  gfddom01  \
# ...

# %%
df['region'].unique()
# Out:
# array(['South Asia', 'Europe & Central Asia',
#        'Middle East & North Africa', 'Sub-Saharan Africa',
#        'Latin America & Caribbean', 'East Asia & Pacific',
#        'North America'], dtype=object)

# %%
df['region_2']= df['region']
df.head(5)
# Out:
#   iso3 iso2  imfn      country      region      income  year  gfddai01  \
# 0  AFG   AF   512  Afghanistan  South Asia  Low income  1960       NaN
# 1  AFG   AF   512  Afghanistan  South Asia  Low income  1961       NaN
# 2  AFG   AF   512  Afghanistan  South Asia  Low income  1962       NaN
# 3  AFG   AF   512  Afghanistan  South Asia  Low income  1963       NaN
# 4  AFG   AF   512  Afghanistan  South Asia  Low income  1964       NaN
#
#    gfddai02  gfddai03  ...  gfddoi19  gfddom01  gfddom02  gfddoe01  gfddoe02  \
# 0       NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
#
#    ny_gdp_mktp_cd  ny_gdp_pcap_kd  ny_gnp_mktp_cd  sp_pop_totl    region_2
# ...

# %%
df['region_2']= df['region_2'].replace(
{
    'South Asia':1,
    'Europe & Central Asia':2,
    'Sub-Saharan Africa':3,
    'Latin America & Caribbean':4,
    'East Asia & Pacific':5,
    'North America':6,
})

df.tail(10)
# Out:
#       iso3 iso2  imfn   country              region      income  year  \
# 12402  ZWE   ZW   698  Zimbabwe  Sub-Saharan Africa  Low income  2008
# 12403  ZWE   ZW   698  Zimbabwe  Sub-Saharan Africa  Low income  2009
# 12404  ZWE   ZW   698  Zimbabwe  Sub-Saharan Africa  Low income  2010
# 12405  ZWE   ZW   698  Zimbabwe  Sub-Saharan Africa  Low income  2011
# 12406  ZWE   ZW   698  Zimbabwe  Sub-Saharan Africa  Low income  2012
# 12407  ZWE   ZW   698  Zimbabwe  Sub-Saharan Africa  Low income  2013
# 12408  ZWE   ZW   698  Zimbabwe  Sub-Saharan Africa  Low income  2014
# 12409  ZWE   ZW   698  Zimbabwe  Sub-Saharan Africa  Low income  2015
# 12410  ZWE   ZW   698  Zimbabwe  Sub-Saharan Africa  Low income  2016
# 12411  ZWE   ZW   698  Zimbabwe  Sub-Saharan Africa  Low income  2017
#
#        gfddai01  gfddai02  gfddai03  ...  gfddoi19  gfddom01  gfddom02  \
# 12402  200.0140   3.12732       NaN  ...       0.0   6.10136       NaN
# ...
